# %%
import cv2
import numpy as np
from matplotlib import pyplot as plt

# %%
img = cv2.imread('farao.jpg')
original = img.copy()
imgray = cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)
ret,thresh = cv2.threshold(imgray,0,255,cv2.THRESH_BINARY+cv2.THRESH_OTSU)
edge = cv2.Canny(img,100,200)
contours, hierarchy = cv2.findContours(edge,cv2.RETR_TREE,cv2.CHAIN_APPROX_SIMPLE)

# %%
con = cv2.drawContours(img, contours, -1, (0,255,0), 3)

# %%
img1 = cv2.imread('mikono.jpg')
original1 = img1.copy()
imgray1 = cv2.cvtColor(img1,cv2.COLOR_BGR2GRAY)
ret1,thresh1 = cv2.threshold(imgray1,50,255,cv2.THRESH_BINARY+cv2.THRESH_OTSU)
edge1 = cv2.Canny(imgray1,100,200)
contours1, hierarchy1 = cv2.findContours(edge1,cv2.RETR_TREE,cv2.CHAIN_APPROX_SIMPLE)

# %%
cont1 = cv2.drawContours(img1, contours1, -1, (255, 0,0), 3)

# %%
plt.figure(figsize=(15, 7))
plt.subplot(231),plt.imshow(original),plt.title('Original', fontsize=10)
plt.subplot(232),plt.imshow(edge, 'gray'),plt.title('Canny Edge', fontsize=10)
plt.subplot(233),plt.imshow(con),plt.title('Countor', fontsize=10)
plt.subplot(234),plt.imshow(original1),plt.title('Original', fontsize=10)
plt.subplot(235),plt.imshow(edge1, 'gray'),plt.title('Canny Edge', fontsize=10)
plt.subplot(236),plt.imshow(cont1),plt.title('Countor', fontsize=10)
plt.show()

# %%
nike = cv2.imread('nike.jpg')
original = nike.copy()
nikeray = cv2.cvtColor(nike,cv2.COLOR_BGR2GRAY)
ret,thresh = cv2.threshold(nikeray,0,255,cv2.THRESH_BINARY+cv2.THRESH_OTSU)
edge = cv2.Canny(nike,100,200)
contours, hierarchy = cv2.findContours(edge,cv2.RETR_TREE,cv2.CHAIN_APPROX_SIMPLE)

# %%
con = cv2.drawContours(nike, contours, -1, (0,255,0), 3)

# %%
plt.figure(figsize=(15, 7))
plt.subplot(121),plt.imshow(original),plt.title('Original', fontsize=10)
plt.subplot(122),plt.imshow(con, 'gray'),plt.title('Contour Image', fontsize=10)
# Out:
# (<AxesSubplot:title={'center':'Contour Image'}>,
# ...
#  Text(0.5, 1.0, 'Contour Image'))

# %%
con.shape
# Out:
# (194, 260, 3)

# %%
nike2 = cv2.imread('nike.jpg')
original2 = nike2.copy()
nike2ray = cv2.cvtColor(nike2,cv2.COLOR_BGR2GRAY)
ret,thresh = cv2.threshold(nike2ray,0,255,cv2.THRESH_BINARY+cv2.THRESH_OTSU)
edge = cv2.Canny(nike2,100,200)
contours2, hierarchy = cv2.findContours(edge,cv2.RETR_TREE,cv2.CHAIN_APPROX_NONE)

# %%
con2 = cv2.drawContours(nike2, contours2[1], -1, (0,255,0), 3)

# %%
con2.shape
# Out:
# (194, 260, 3)

# %%
plt.figure(figsize=(15, 7))
plt.subplot(121),plt.imshow(original2),plt.title('Original', fontsize=10)
plt.subplot(122),plt.imshow(con2, 'gray'),plt.title('Contour Image', fontsize=10)
# Out:
# (<AxesSubplot:title={'center':'Contour Image'}>,
# ...
#  Text(0.5, 1.0, 'Contour Image'))

# %%
im = cv2.imread('nike.jpg')
# ret,thresh = cv2.threshold(im,127,255,0)
imgray = cv2.cvtColor(im,cv2.COLOR_BGR2GRAY)

# %%
# ret,th=cv2.threshold(imgray,0,255,cv2.THRESH_BINARY+cv2.THRESH_OTSU)
ret,th=cv2.threshold(imgray,127,255,0)
contours,hierarchy = cv2.findContours(th, cv2.RETR_TREE,cv2.CHAIN_APPROX_NONE)
cnt = contours[1]
M = cv2.moments(cnt)

# %%
im.shape
# Out:
# (194, 260, 3)

# %%
cx = int(M['m10']/M['m00'])
cy = int(M['m01']/M['m00'])

# %%
img = np.zeros(im.shape, np.uint8)
img = cv2.circle(img,(cx,cy),3,(0,255,0),2)

# %%
img = cv2.drawContours(img, contours[1], -1, (0,255,0), 3)

# %%
plt.figure(figsize=(15, 7))
plt.subplot(121),plt.imshow(im),plt.title('Original', fontsize=10)
plt.subplot(122),plt.imshow(img, 'gray'),plt.title('Contour Image', fontsize=10)
# Out:
# (<AxesSubplot:title={'center':'Contour Image'}>,
# ...
#  Text(0.5, 1.0, 'Contour Image'))

# %%
epsilon = 0.0001*cv2.arcLength(cnt,True)
approx = cv2.approxPolyDP(cnt,epsilon,True)

# %%
imgA = np.zeros(im.shape, np.uint8)
imgA = cv2.drawContours(imgA, approx, -1,(255,0,0), 1)

# %%
plt.figure(figsize=(15, 7))
plt.subplot(121),plt.imshow(img),plt.title('Original', fontsize=10)
plt.subplot(122),plt.imshow(imgA, 'gray'),plt.title('Contour Image', fontsize=10)
# Out:
# (<AxesSubplot:title={'center':'Contour Image'}>,
# ...
#  Text(0.5, 1.0, 'Contour Image'))

# %%
epsilon = 0.1*cv2.arcLength(cnt,True)
approx = cv2.approxPolyDP(cnt,epsilon,True)

# %%
imgA = np.zeros(im.shape, np.uint8)
img1A = cv2.drawContours(imgA, [approx], -1,(255,0,0), 1)

# %%
plt.figure(figsize=(15, 7))
plt.subplot(121),plt.imshow(img),plt.title('Original', fontsize=10)
plt.subplot(122),plt.imshow(img1A, 'gray'),plt.title('Contour Image', fontsize=10)
# Out:
# (<AxesSubplot:title={'center':'Contour Image'}>,
# ...
#  Text(0.5, 1.0, 'Contour Image'))

# %%
img= cv2.imread('nike.jpg')
im = img.copy()
imgray = cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)
ret,th=cv2.threshold(imgray,0,255,cv2.THRESH_BINARY+cv2.THRESH_OTSU)

# %%
contours, hierarchy=cv2.findContours(th,cv2.RETR_TREE,cv2.CHAIN_APPROX_SIMPLE)
print("Number of Contours found = " + str(len(contours)))
# Out:
# Number of Contours found = 2

# %%
im = cv2.drawContours(img, contours, -1, (0,255,0), 3)
    
plt.figure(figsize=(15, 10))
plt.subplot(121),plt.imshow(imgray, 'gray')
plt.title('Original Image', fontsize=25)
plt.subplot(122),plt.imshow(im, 'gray')
plt.title('Contour Image', fontsize=25)
plt.show()

# %%
cnt = contours[1]
M = cv2.moments(cnt)
print(M)
# Out:
# {'m00': 5157.5, 'm10': 669820.5, 'm01': 407657.8333333333, 'm20': 97679630.58333333, 'm11': 56592505.45833333, 'm02': 36608653.916666664, 'm30': 15486419062.75, 'm21': 8601690358.05, 'm12': 5439187775.75, 'm03': 3690108311.15, 'mu20': 10687967.525601864, 'mu11': 3648719.9513532, 'mu02': 4386664.759511497, 'mu30': 24303987.40178299, 'mu21': -66819852.08142352, 'mu12': 107906067.4793011, 'mu03': 103036854.09474659, 'nu20': 0.4018062171261817, 'nu11': 0.13717092211350976, 'nu02': 0.16491341020619266, 'nu30': 0.012722704485239654, 'nu21': -0.034979002322763304, 'nu12': 0.0564869042271953, 'nu03': 0.053937957754209724}

# %%
cx = int(M['m10']/M['m00'])
cy = int(M['m01']/M['m00'])

# %%
img = np.zeros(im.shape, np.uint8)
img = cv2.circle(img,(cx,cy),3,(255,255,0),2)
img = cv2.drawContours(img, contours[1], -1, (0,255,0), 3)

# %%
plt.figure(figsize=(15, 10))
plt.subplot(121),plt.imshow(imgray, 'gray')
plt.title('Original Image', fontsize=25)
plt.subplot(122),plt.imshow(img, 'gray')
plt.title('Contour Image', fontsize=25)
plt.show()

# %%
hull=cv2.convexHull(cnt)

# %%
imgb = img.copy()
imgb = cv2.drawContours(imgb, [hull], -1, (255,0,0), 3)

# %%
plt.figure(figsize=(9, 5))
plt.imshow(imgb, 'gray')
plt.show()

# %%
(x,y),radius=cv2.minEnclosingCircle(cnt)
center=(int(x),int(y))
radius=int(radius)
img=cv2.circle(img,center,radius,(255,0,0),2)

# %%
plt.figure(figsize=(10, 7))
plt.imshow(img, 'gray')
plt.show()
